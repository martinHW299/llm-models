# %%
# Imports
from google import genai
from google.genai import types
from openai import OpenAI
from dotenv import load_dotenv
import pandas as pd
import os
import json
import time
import base64
import re
import openpyxl
import concurrent.futures
import importlib
import prompts
importlib.reload(prompts)
# Out:
# <module 'prompts' from '/Users/martinhachiya/dev/nutria_backbone/nutria_solution/prompts.py'>

# %%
load_dotenv(override=True)

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

gemini_client = genai.Client()
openai_client = OpenAI()

gemini_model = os.getenv("GEMINI_MODEL")
openai_model = os.getenv("OPENAI_MODEL")

images_folder_path = os.getenv("IMG_PATH")
output_folder_path = os.getenv("OUTPUT_FOLDER_PATH")

# %%
def parse_json(text):
    """Parse JSON from model response with better error handling"""
    if not text:
        raise ValueError("Input text is None or empty")
    
    if not isinstance(text, str):
        raise ValueError(f"Input text is not a string, got {type(text)}")
    
    # Clean the text
    text = text.strip()
    
    # Try direct parsing first
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        pass
    
    # Try to find JSON between first { and last }
    try:
        start = text.find('{')
        end = text.rfind('}')
        if start != -1 and end != -1 and end > start:
            json_str = text[start:end+1]
            return json.loads(json_str)
    except json.JSONDecodeError:
        pass
    
    # Try to extract JSON using a more robust regex
    import re
    json_pattern = r'\{[^{}]*(?:\{[^{}]*\}[^{}]*)*\}'
    matches = re.findall(json_pattern, text, re.DOTALL)
    
    for match in matches:
        try:
            return json.loads(match)
        except json.JSONDecodeError:
            continue
    
    # If we get here, no valid JSON was found
    raise ValueError(f"No valid JSON found in text: {text[:200]}...")
    
def count_images(folder_path):
    """Count numbered images"""
    count = 0
    index = 1
    while os.path.exists(os.path.join(folder_path, f"{index}.jpg")):
        count += 1
        index += 1
    return count

# %%
def step1_gpt_serving_size(image):
    try:
        response = openai_client.chat.completions.create(
            model=openai_model,
            messages=[
            {
                "role": "system",
                "content": prompts.SYSTEM_PROMPT_PORTION_EXPERT
            },  
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": prompts.build_serving_estimation_prompt()},
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/jpeg;base64,{image}"
                        }
                    }
                ]
            }],
            max_tokens=500,
            temperature=0.1,
            response_format={"type": "json_object"}
        )
        
        try:
            data = parse_json(response.choices[0].message.content)
        except Exception as e:
            return {'success': False, 'error': f"No valid JSON found in the response text: {str(e)}"}
        return {
            'success': True,
            'description': data.get('description'),
            'serving_size': float(data.get('serving_size', 0)),
        }

    except Exception as e:
        return {'success': False, 'error': str(e)}
    

def step2_nutrition_gemini(image, description, serving_size):
    try:
        nutrition_prompt = prompts.build_nutrition_estimation_prompt(description, serving_size)

        response = gemini_client.models.generate_content(
            model=gemini_model,
            contents=[
                image,
                nutrition_prompt,
            ],
            config=types.GenerateContentConfig(
                temperature=0.1,
                response_mime_type="application/json",
                # top_p=0.95,
                max_output_tokens=500
            )
        )

        if not response or not getattr(response, "text", None):
            return {'success': False, 'error': 'Gemini response is empty or missing `.text`'}
        
        try:
            data = parse_json(response.text)
        except Exception as e:
            return {'success': False, 'error': f"No valid JSON found in the response text: {str(e)}"}

        return {
            'success': True,
            'description': data.get('description'),
            'calories': float(data.get('calories', 0)),
            'proteins': float(data.get('proteins', 0)),
            'carbohydrates': float(data.get('carbohydrates', 0)),
            'fats': float(data.get('fats', 0)),
            'serving_size': float(data.get('serving_size', 0))
        }
    except Exception as e:
        return {'success': False, 'error': str(e)}

# %%
def analyze_image_chained(image_path, index):
    """Complete chained analysis for one image"""
    start_time = time.time()
    file_name = os.path.basename(image_path)

    with open(image_path, "rb") as f:
            image_base64 = base64.b64encode(f.read()).decode("utf-8")

    print(f"\n🔄 Processing {index}: {file_name}")

    print("  Step 1: Serving size (GPT)...")
    serving_size = step1_gpt_serving_size(image_base64)

    if not serving_size['success']:
        return {'success': False, 'error': f"Step 1 failed: {serving_size['error']}", 'index': index}
    
    print(f"    → {serving_size['serving_size']}g - {serving_size['description'][:50]}...")
    if not serving_size.get("description"):
        return {'success': False, 'error': "Step 1 returned empty description", 'index': index}

    time.sleep(2)

    print("  Step 2: Nutrition analysis (Gemini)...")
    nutrition = step2_nutrition_gemini(image_base64, serving_size['description'], serving_size['serving_size'])
    
    if not nutrition.get('success'):
        print(f"❌ Step 2 failed: {nutrition}")
        return {'success': False, 'error': f"Step 2 failed: {nutrition.get('error', 'Unknown error')}", 'index': index}

    print(f"    → {nutrition}")

    total_time = time.time() - start_time
    time.sleep(2)
    print(f"  ✅ Complete! {nutrition['calories']} kcal in {total_time:.1f}s")

    return {
        'success': True,
        'index': index,
        'file_name': file_name,
        'serving_size': serving_size,
        'nutrition': nutrition,
        'processing_time': total_time
    }

# %%
# Process dataset
def process_chained_dataset(file_name, folder_path, start=1, end=None):
    """Process images with chained analysis"""
    
    total_images = count_images(folder_path)
    if end is None:
        end = total_images
    end = min(end, total_images)
    
    print(f"🚀 Processing images {start} to {end} ({end-start+1} total)")
    
    results = []
    successful = 0
    
    for i in range(start, end + 1):
        image_path = os.path.join(folder_path, f"{i}.jpg")
        result = analyze_image_chained(image_path, i)
        results.append(result)
        
        if result['success']:
            successful += 1
    
    print(f"\n🎉 Completed! {successful}/{len(results)} successful")
    
    # Save results
    output_file = f"{file_name}.json"
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(results, f, indent=2, ensure_ascii=False)
    
    print(f"📁 Results saved to: {output_file}")
    return results

# %%
def export_to_excel(file_name):
    """Export results to Excel"""
    with open(f"{file_name}.json", 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # Prepare final results
    final_results = []
    for item in data:
        if item['success']:
            nutrition = item['nutrition']
            final_results.append({
                'id': item['index'],
                'description': nutrition['description'],
                'serving_size': nutrition['serving_size'],
                'calories': nutrition['calories'],
                'proteins': nutrition['proteins'],
                'carbohydrates': nutrition['carbohydrates'],
                'fats': nutrition['fats']
            })
    
    # Create DataFrame and export
    df = pd.DataFrame(final_results)
    output_path = os.path.join(output_folder_path, f"{file_name}.xlsx")
    df.to_excel(output_path, index=False)
    
    print(f"✅ Excel exported: {output_path}")
    print(f"📊 {len(final_results)} successful analyses")
    
    return output_path

# %%
file_name = "nutria_gpt_gemini"

# %%
results = process_chained_dataset(file_name, images_folder_path, start=1, end=count_images(images_folder_path))
# results = process_chained_dataset(file_name, images_folder_path, start=1, end=2)
# Out:
# 🚀 Processing images 1 to 50 (50 total)
#
# 🔄 Processing 1: 1.jpg
#   Step 1: Serving size (GPT)...
#     → 300.0g - Vaso de cerveza rubia...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Vaso de cerveza rubia', 'calories': 126.0, 'proteins': 9.0, 'carbohydrates': 10.8, 'fats': 0.0, 'serving_size': 300.0}
#   ✅ Complete! 126.0 kcal in 10.1s
#
# 🔄 Processing 2: 2.jpg
#   Step 1: Serving size (GPT)...
#     → 300.0g - Pasta tipo penne con salsa de tomate y albahaca...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Pasta tipo penne con salsa de tomate y albahaca', 'calories': 399.0, 'proteins': 13.2, 'carbohydrates': 76.5, 'fats': 6.3, 'serving_size': 300.0}
#   ✅ Complete! 399.0 kcal in 13.7s
#
# 🔄 Processing 3: 3.jpg
#   Step 1: Serving size (GPT)...
#     → 180.0g - Croissant integral con semillas, huevos revueltos,...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Croissant integral con semillas, huevos revueltos, salmón ahumado y tomates cherry', 'calories': 418.2, 'proteins': 18.6, 'carbohydrates': 36.0, 'fats': 21.6, 'serving_size': 180.0}
#   ✅ Complete! 418.2 kcal in 11.9s
#
# 🔄 Processing 4: 4.jpg
#   Step 1: Serving size (GPT)...
#     → 280.0g - Carne de cerdo con salsa, tocino picado y papas fr...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Carne de cerdo con salsa, tocino picado y papas fritas', 'calories': 670.0, 'proteins': 32.0, 'carbohydrates': 40.0, 'fats': 45.0, 'serving_size': 280.0}
#   ✅ Complete! 670.0 kcal in 16.5s
#
# 🔄 Processing 5: 5.jpg
#   Step 1: Serving size (GPT)...
#     → 220.0g - Arroz blanco con carne de cerdo en salsa y ensalad...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Arroz blanco con carne de cerdo en salsa y ensalada de repollo morado', 'calories': 418.0, 'proteins': 16.5, 'carbohydrates': 55.0, 'fats': 13.2, 'serving_size': 220.0}
#   ✅ Complete! 418.0 kcal in 9.6s
#
# 🔄 Processing 6: 6.jpg
#   Step 1: Serving size (GPT)...
#     → 320.0g - Bistec de carne con salsa, acompañado de vegetales...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Bistec de carne con salsa, acompañado de vegetales al vapor y decoración de rodajas de naranja y zanahoria', 'calories': 416.0, 'proteins': 38.4, 'carbohydrates': 22.4, 'fats': 19.2, 'serving_size': 320.0}
#   ✅ Complete! 416.0 kcal in 10.8s
#
# 🔄 Processing 7: 7.jpg
#   Step 1: Serving size (GPT)...
#     → 180.0g - Medio aguacate y filetes de salmón ahumado...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Medio aguacate y filetes de salmón ahumado', 'calories': 302.4, 'proteins': 14.4, 'carbohydrates': 10.8, 'fats': 22.8, 'serving_size': 180.0}
#   ✅ Complete! 302.4 kcal in 13.8s
#
# 🔄 Processing 8: 8.jpg
#   Step 1: Serving size (GPT)...
#     → 30.0g - Taza de café espresso parcialmente consumida...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Taza de café espresso parcialmente consumida', 'calories': 2.0, 'proteins': 0.2, 'carbohydrates': 0.1, 'fats': 0.0, 'serving_size': 30.0}
#   ✅ Complete! 2.0 kcal in 9.9s
#
# 🔄 Processing 9: 9.jpg
#   Step 1: Serving size (GPT)...
#     → 250.0g - Taza de café con leche...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Taza de café con leche', 'calories': 107.5, 'proteins': 7.5, 'carbohydrates': 12.5, 'fats': 4.0, 'serving_size': 250.0}
#   ✅ Complete! 107.5 kcal in 8.7s
#
# 🔄 Processing 10: 10.jpg
#   Step 1: Serving size (GPT)...
#     → 500.0g - Botella de agua de plástico con tapa azul...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Botella de agua de plástico con tapa azul', 'calories': 0.0, 'proteins': 0.0, 'carbohydrates': 0.0, 'fats': 0.0, 'serving_size': 500.0}
#   ✅ Complete! 0.0 kcal in 8.3s
#
# 🔄 Processing 11: 11.jpg
#   Step 1: Serving size (GPT)...
#     → 150.0g - Vaso de vino blanco...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Vaso de vino blanco', 'calories': 123.75, 'proteins': 0.19, 'carbohydrates': 3.83, 'fats': 0.0, 'serving_size': 150.0}
#   ✅ Complete! 123.75 kcal in 8.8s
#
# 🔄 Processing 12: 12.jpg
#   Step 1: Serving size (GPT)...
#     → 90.0g - Seis rodajas de salchichón o salami...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Seis rodajas de salchichón o salami', 'calories': 418.2, 'proteins': 23.4, 'carbohydrates': 3.6, 'fats': 36.0, 'serving_size': 90.0}
#   ✅ Complete! 418.2 kcal in 13.3s
#
# 🔄 Processing 13: 13.jpg
#   Step 1: Serving size (GPT)...
#     → 120.0g - Banana entera...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Banana entera', 'calories': 105.0, 'proteins': 1.3, 'carbohydrates': 27.0, 'fats': 0.4, 'serving_size': 120.0}
#   ✅ Complete! 105.0 kcal in 7.2s
#
# 🔄 Processing 14: 14.jpg
#   Step 1: Serving size (GPT)...
#     → 320.0g - Bistec a la parrilla con ensalada de lechuga y rod...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Bistec a la parrilla con ensalada de lechuga y rodajas de berenjena y calabacín a la parrilla, acompañado de una porción de mote', 'calories': 464.8, 'proteins': 35.2, 'carbohydrates': 38.4, 'fats': 19.2, 'serving_size': 320.0}
#   ✅ Complete! 464.8 kcal in 13.5s
#
# 🔄 Processing 15: 15.jpg
#   Step 1: Serving size (GPT)...
#     → 40.0g - Mezcla de frutos secos tostados incluyendo almendr...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Mezcla de frutos secos tostados incluyendo almendras, maní y nueces de la india', 'calories': 234.4, 'proteins': 9.6, 'carbohydrates': 8.0, 'fats': 19.2, 'serving_size': 40.0}
#   ✅ Complete! 234.4 kcal in 9.2s
#
# 🔄 Processing 16: 16.jpg
#   Step 1: Serving size (GPT)...
#     → 200.0g - vaso de té negro con rodaja de limón...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'vaso de té negro con rodaja de limón', 'calories': 2.4, 'proteins': 0.4, 'carbohydrates': 0.4, 'fats': 0.0, 'serving_size': 200.0}
#   ✅ Complete! 2.4 kcal in 12.2s
#
# 🔄 Processing 17: 17.jpg
#   Step 1: Serving size (GPT)...
#     → 180.0g - Taza de café con espuma acompañado de dos chocolat...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Taza de café con espuma acompañado de dos chocolates en forma de trébol', 'calories': 110.0, 'proteins': 2.0, 'carbohydrates': 18.0, 'fats': 4.0, 'serving_size': 180.0}
#   ✅ Complete! 110.0 kcal in 11.5s
#
# 🔄 Processing 18: 18.jpg
#   Step 1: Serving size (GPT)...
#     → 150.0g - Dos huevos fritos con tiras de tocino...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Dos huevos fritos con tiras de tocino', 'calories': 311.25, 'proteins': 19.5, 'carbohydrates': 1.5, 'fats': 24.0, 'serving_size': 150.0}
#   ✅ Complete! 311.25 kcal in 10.8s
#
# 🔄 Processing 19: 19.jpg
#   Step 1: Serving size (GPT)...
#     → 40.0g - barra de chocolate oscuro con cuatro cuadros...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'barra de chocolate oscuro con cuatro cuadros', 'calories': 220.0, 'proteins': 2.4, 'carbohydrates': 24.0, 'fats': 14.4, 'serving_size': 40.0}
#   ✅ Complete! 220.0 kcal in 11.4s
#
# 🔄 Processing 20: 20.jpg
#   Step 1: Serving size (GPT)...
#     → 350.0g - Vaso de agua con hielo...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Vaso de agua con hielo', 'calories': 0.0, 'proteins': 0.0, 'carbohydrates': 0.0, 'fats': 0.0, 'serving_size': 350.0}
#   ✅ Complete! 0.0 kcal in 13.3s
#
# 🔄 Processing 21: 21.jpg
#   Step 1: Serving size (GPT)...
#     → 250.0g - Vaso de agua...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Vaso de agua', 'calories': 0.0, 'proteins': 0.0, 'carbohydrates': 0.0, 'fats': 0.0, 'serving_size': 250.0}
#   ✅ Complete! 0.0 kcal in 11.4s
#
# 🔄 Processing 22: 22.jpg
#   Step 1: Serving size (GPT)...
#     → 250.0g - Taza de chocolate caliente...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Taza de chocolate caliente', 'calories': 231.25, 'proteins': 4.38, 'carbohydrates': 42.5, 'fats': 5.63, 'serving_size': 250.0}
#   ✅ Complete! 231.25 kcal in 17.0s
#
# 🔄 Processing 23: 23.jpg
#   Step 1: Serving size (GPT)...
#     → 90.0g - mezcla de frutos secos (anacardos, almendras, maní...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'mezcla de frutos secos (anacardos, almendras, maní, ciruelas pasas) con palitos salados', 'calories': 486.0, 'proteins': 14.4, 'carbohydrates': 32.4, 'fats': 32.4, 'serving_size': 90.0}
#   ✅ Complete! 486.0 kcal in 13.6s
#
# 🔄 Processing 24: 24.jpg
#   Step 1: Serving size (GPT)...
#     → 150.0g - Vino tinto en copa...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Vino tinto en copa', 'calories': 124.5, 'proteins': 0.0, 'carbohydrates': 3.8, 'fats': 0.0, 'serving_size': 150.0}
#   ✅ Complete! 124.5 kcal in 12.5s
#
# 🔄 Processing 25: 25.jpg
#   Step 1: Serving size (GPT)...
#     → 320.0g - Pechuga de pollo salteada con vegetales mixtos en ...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Pechuga de pollo salteada con vegetales mixtos en salsa', 'calories': 416.0, 'proteins': 48.0, 'carbohydrates': 22.4, 'fats': 16.0, 'serving_size': 320.0}
#   ✅ Complete! 416.0 kcal in 77.3s
#
# 🔄 Processing 26: 26.jpg
#   Step 1: Serving size (GPT)...
#     → 100.0g - Dos huevos enteros con cáscara...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Dos huevos enteros con cáscara', 'calories': 143.0, 'proteins': 12.6, 'carbohydrates': 0.7, 'fats': 9.7, 'serving_size': 100.0}
#   ✅ Complete! 143.0 kcal in 14.9s
#
# 🔄 Processing 27: 27.jpg
#   Step 1: Serving size (GPT)...
#     → 150.0g - Manzana fresca...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Manzana fresca', 'calories': 81.0, 'proteins': 0.38, 'carbohydrates': 21.0, 'fats': 0.19, 'serving_size': 150.0}
#   ✅ Complete! 81.0 kcal in 9.0s
#
# 🔄 Processing 28: 28.jpg
#   Step 1: Serving size (GPT)...
#     → 300.0g - Pizza Margherita con salsa de tomate, queso mozzar...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Pizza Margherita con salsa de tomate, queso mozzarella y hojas de albahaca', 'calories': 675.0, 'proteins': 36.0, 'carbohydrates': 75.0, 'fats': 24.0, 'serving_size': 300.0}
#   ✅ Complete! 675.0 kcal in 10.5s
#
# 🔄 Processing 29: 29.jpg
#   Step 1: Serving size (GPT)...
#     → 360.0g - Tres mandarinas frescas...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Tres mandarinas frescas', 'calories': 197.4, 'proteins': 2.7, 'carbohydrates': 50.4, 'fats': 0.72, 'serving_size': 360.0}
#   ✅ Complete! 197.4 kcal in 11.0s
#
# 🔄 Processing 30: 30.jpg
#   Step 1: Serving size (GPT)...
#     → 220.0g - Ensalada de pasta tricolor con tomate y hojas verd...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Ensalada de pasta tricolor con tomate y hojas verdes', 'calories': 259.6, 'proteins': 8.8, 'carbohydrates': 48.4, 'fats': 4.4, 'serving_size': 220.0}
#   ✅ Complete! 259.6 kcal in 10.6s
#
# 🔄 Processing 31: 31.jpg
#   Step 1: Serving size (GPT)...
#     → 80.0g - Dos rebanadas de pan artesanal...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Dos rebanadas de pan artesanal', 'calories': 214.4, 'proteins': 7.2, 'carbohydrates': 42.4, 'fats': 2.4, 'serving_size': 80.0}
#   ✅ Complete! 214.4 kcal in 17.0s
#
# 🔄 Processing 32: 32.jpg
#   Step 1: Serving size (GPT)...
#     → 280.0g - Muslo de pollo asado con calabacín y cebolla salte...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Muslo de pollo asado con calabacín y cebolla salteados', 'calories': 489.6, 'proteins': 39.2, 'carbohydrates': 19.6, 'fats': 28.0, 'serving_size': 280.0}
#   ✅ Complete! 489.6 kcal in 14.3s
#
# 🔄 Processing 33: 33.jpg
#   Step 1: Serving size (GPT)...
#     → 250.0g - Ensalada de lechuga con pasta tipo codito en salsa...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Ensalada de lechuga con pasta tipo codito en salsa cremosa con trozos de jamón', 'calories': 305.0, 'proteins': 13.75, 'carbohydrates': 31.25, 'fats': 15.0, 'serving_size': 250.0}
#   ✅ Complete! 305.0 kcal in 10.8s
#
# 🔄 Processing 34: 34.jpg
#   Step 1: Serving size (GPT)...
#     → 150.0g - Ensalada de hojas verdes mixtas con zanahoria rall...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Ensalada de hojas verdes mixtas con zanahoria rallada y tomates cherry', 'calories': 37.5, 'proteins': 2.25, 'carbohydrates': 6.75, 'fats': 0.45, 'serving_size': 150.0}
#   ✅ Complete! 37.5 kcal in 11.5s
#
# 🔄 Processing 35: 35.jpg
#   Step 1: Serving size (GPT)...
#     → 80.0g - Dos barras de queso tipo quesillo o queso fresco...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Dos barras de queso tipo quesillo o queso fresco', 'calories': 176.0, 'proteins': 16.0, 'carbohydrates': 2.4, 'fats': 12.8, 'serving_size': 80.0}
#   ✅ Complete! 176.0 kcal in 8.5s
#
# 🔄 Processing 36: 36.jpg
#   Step 1: Serving size (GPT)...
#     → 320.0g - Arroz con huevo frito y plátanos fritos...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Arroz con huevo frito y plátanos fritos', 'calories': 672.8, 'proteins': 18.6, 'carbohydrates': 97.3, 'fats': 26.9, 'serving_size': 320.0}
#   ✅ Complete! 672.8 kcal in 12.9s
#
# 🔄 Processing 37: 37.jpg
#   Step 1: Serving size (GPT)...
#     → 350.0g - Charque de carne seca con dos huevos cocidos y una...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Charque de carne seca con dos huevos cocidos y una porción de queso fresco', 'calories': 679.0, 'proteins': 78.6, 'carbohydrates': 2.1, 'fats': 42.3, 'serving_size': 350.0}
#   ✅ Complete! 679.0 kcal in 7.2s
#
# 🔄 Processing 38: 38.jpg
#   Step 1: Serving size (GPT)...
#     → 350.0g - Sopa cremosa con trozos de pollo, verduras y fideo...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Sopa cremosa con trozos de pollo, verduras y fideos', 'calories': 270.0, 'proteins': 20.0, 'carbohydrates': 25.0, 'fats': 10.0, 'serving_size': 350.0}
#   ✅ Complete! 270.0 kcal in 6.3s
#
# 🔄 Processing 39: 39.jpg
#   Step 1: Serving size (GPT)...
#     → 320.0g - Filete de carne con arroz blanco y ensalada de tom...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Filete de carne con arroz blanco y ensalada de tomate con cebolla y perejil', 'calories': 497.6, 'proteins': 34.4, 'carbohydrates': 52.8, 'fats': 17.6, 'serving_size': 320.0}
#   ✅ Complete! 497.6 kcal in 7.4s
#
# 🔄 Processing 40: 40.jpg
#   Step 1: Serving size (GPT)...
#     → 450.0g - Plato de carne de res en trozos con papas fritas, ...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Plato de carne de res en trozos con papas fritas, rodajas de tomate, cebolla, pimiento verde y bolas de queso fresco', 'calories': 774.0, 'proteins': 43.2, 'carbohydrates': 63.9, 'fats': 40.5, 'serving_size': 450.0}
#   ✅ Complete! 774.0 kcal in 10.3s
#
# 🔄 Processing 41: 41.jpg
#   Step 1: Serving size (GPT)...
#     → 350.0g - Sopa de maní con pollo, papa y maíz...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Sopa de maní con pollo, papa y maíz', 'calories': 315.0, 'proteins': 21.0, 'carbohydrates': 35.0, 'fats': 12.6, 'serving_size': 350.0}
#   ✅ Complete! 315.0 kcal in 7.1s
#
# 🔄 Processing 42: 42.jpg
#   Step 1: Serving size (GPT)...
#     → 350.0g - Plato con charque desmenuzado, papa cocida, huevo ...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Plato con charque desmenuzado, papa cocida, huevo cocido y una porción de arroz blanco', 'calories': 518.8, 'proteins': 42.7, 'carbohydrates': 57.4, 'fats': 14.7, 'serving_size': 350.0}
#   ✅ Complete! 518.8 kcal in 7.0s
#
# 🔄 Processing 43: 43.jpg
#   Step 1: Serving size (GPT)...
#     → 350.0g - Pechuga de pollo con salsa de tomate y arvejas, ar...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Pechuga de pollo con salsa de tomate y arvejas, arroz blanco, ensalada de cebolla y pimiento, puré de papa y ensalada de champiñones con mayonesa', 'calories': 588.8, 'proteins': 42.7, 'carbohydrates': 63.7, 'fats': 21.0, 'serving_size': 350.0}
#   ✅ Complete! 588.8 kcal in 12.1s
#
# 🔄 Processing 44: 44.jpg
#   Step 1: Serving size (GPT)...
#     → 300.0g - Vaso de té frío con hielo...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Vaso de té frío con hielo', 'calories': 1.2, 'proteins': 0.0, 'carbohydrates': 0.3, 'fats': 0.0, 'serving_size': 300.0}
#   ✅ Complete! 1.2 kcal in 8.0s
#
# 🔄 Processing 45: 45.jpg
#   Step 1: Serving size (GPT)...
#     → 320.0g - Bistec con salsa blanca y papas paja...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Bistec con salsa blanca y papas paja', 'calories': 672.8, 'proteins': 48.0, 'carbohydrates': 41.6, 'fats': 38.4, 'serving_size': 320.0}
#   ✅ Complete! 672.8 kcal in 6.8s
#
# 🔄 Processing 46: 46.jpg
#   Step 1: Serving size (GPT)...
#     → 350.0g - Vaso de api morado tradicional boliviano...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Vaso de api morado tradicional boliviano', 'calories': 210.0, 'proteins': 7.0, 'carbohydrates': 42.0, 'fats': 1.75, 'serving_size': 350.0}
#   ✅ Complete! 210.0 kcal in 6.2s
#
# 🔄 Processing 47: 47.jpg
#   Step 1: Serving size (GPT)...
#     → 350.0g - Carne guisada con arroz blanco y tajadas de plátan...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Carne guisada con arroz blanco y tajadas de plátano frito', 'calories': 648.5, 'proteins': 27.3, 'carbohydrates': 77.0, 'fats': 27.2, 'serving_size': 350.0}
#   ✅ Complete! 648.5 kcal in 6.4s
#
# 🔄 Processing 48: 48.jpg
#   Step 1: Serving size (GPT)...
#     → 250.0g - Arroz con leche espeso con canela espolvoreada...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Arroz con leche espeso con canela espolvoreada', 'calories': 275.0, 'proteins': 5.0, 'carbohydrates': 55.0, 'fats': 5.0, 'serving_size': 250.0}
#   ✅ Complete! 275.0 kcal in 44.8s
#
# 🔄 Processing 49: 49.jpg
#   Step 1: Serving size (GPT)...
#     → 320.0g - Sándwich con dos hamburguesas de carne, rodajas de...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Sándwich con dos hamburguesas de carne, rodajas de papa frita, huevo frito y pico de gallo', 'calories': 710.4, 'proteins': 44.8, 'carbohydrates': 52.8, 'fats': 41.6, 'serving_size': 320.0}
#   ✅ Complete! 710.4 kcal in 7.3s
#
# 🔄 Processing 50: 50.jpg
#   Step 1: Serving size (GPT)...
#     → 350.0g - Cangrejos cocidos con maíz mote y rodajas de limón...
#   Step 2: Nutrition analysis (Gemini)...
#     → {'success': True, 'description': 'Cangrejos cocidos con maíz mote y rodajas de limón', 'calories': 301.0, 'proteins': 45.5, 'carbohydrates': 17.5, 'fats': 8.0, 'serving_size': 350.0}
#   ✅ Complete! 301.0 kcal in 6.3s
#
# 🎉 Completed! 50/50 successful
# 📁 Results saved to: nutria_gpt_gemini.json

# %%
excel_path = export_to_excel(file_name)
print(f"\n🎯 Done! Check: {excel_path}")
# Out:
# ✅ Excel exported: /Users/martinhachiya/dev/datasets/nutria_backbone/llm_response/nutria_gpt_gemini.xlsx
# 📊 50 successful analyses
#
# 🎯 Done! Check: /Users/martinhachiya/dev/datasets/nutria_backbone/llm_response/nutria_gpt_gemini.xlsx
